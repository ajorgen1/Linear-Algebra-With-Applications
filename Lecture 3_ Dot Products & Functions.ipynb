# %% [markdown]
# ## 3.1 The Dot Product
#
# How should we define "vector-vector multiplication"? So far we have done vector-scalar multiplication: $\lambda\vec{v}$. We know that this kind of multiplication changes the length and (possibly) the direction of $\vec{v}$.
#
# One of the most useful ways to multiply vectors is the <u>dot product</u> (also called the "scalar" or "inner" product).
#
# **Definition**. For two vectors $\vec{u}$ and $\vec{v}$:
#
# $\vec{u} \cdot \vec{v} = \Sigma_{i=1}^n u_iv_i$.
#
# **Examples**. Find the following dot products:
#
# a) $<1, 2, -2> \cdot <-2, 8, 4>$
#
# b) $[1, 2] \cdot [2, -1]$.

# %% [markdown]
# ### Matrix Multiplication.
#
# **Definition**. A <u>matrix</u> is a mathematical object that consists of an *ordered* collection of vectors. A general *m* by *n* dimensional matrix is:
#
# \begin{align} A = \begin{bmatrix}
#     a_{11} & a_{12} & \dots \\
#     \vdots & \ddots & \\
#     a_{m1} &        & a_{mn}
#     \end{bmatrix} .
# \end{align}
#
# We will study matrices and their properties in the second half of this course. One of the key concepts that we will learn is that matrix-matrix multiplication $AB$ (think matrix $A$ times matrix $B$, in that order) is only defined if $A$ has the same number of columns as the number of rows in $B$. Furthermore, $AB$ will be a matrix that has the same number of rows as $A$ and same number of columns as $B$.
#
# Why is this coming up now? It can be helpful to think of vectors as "thin" matrices.
#
# **Discuss**. If we think of the vectors in the previous examples as matrices, what are their dimensions?
#
# **Exercise**. Suppose that $\vec{u}$ and $\vec{v}$ are column vectors in $\mathbb{R}^n$. Use the transpose operator to write $\vec{u}\cdot\vec{v}$ as matrix-matrix multiplication.

# %% [markdown]
# ### The Dot Product in Python.
#
# The ```dot()``` function lives in the ```numpy``` library and can be used to compute the dot product for vectors in Python.

# %%
import numpy as np

u = np.array([[1], [2], [-2]])
v = np.array([[-2], [8], [4]])

# %% [markdown]
# **Definition**. The <u>mean</u> of a vector is the *average* of its components: for a vector $\vec{x} \in \mathbb{R}^n$, $\bar{x} = \dfrac{\sum_{i=1}^{n}x_i}{n}$.

# %% [markdown]
# **Exercise**. How could you use the dot-product and a ```ones``` vector to compute $\bar{x}$?
#
# a) Write out (by hand) a mathematical equation for $\bar{x}$.
#
# b) Implement this equation using Python code. Explore finding $n$ using the built-in ```len()``` function. What are the similarities and differences between and an ```ndarray``` with a shape of ```(1, 1)``` and a ```float```?

# %% [markdown]
# **Exercise**. Express $||\vec{v}||$ in terms of a dot product.

# %% [markdown]
# ### Properties of the Dot Product.
#
# a) $\vec{u} \cdot \vec{v} = 0$ if and only if $\vec{u}$ and $\vec{v}$ are "orthogonal."
#
# b) If $\vec{u}$ and $\vec{v}$ point in the same direction then $\vec{u} \cdot \vec{v} = ||\vec{u}||||\vec{v}||$.
#
# c) If $\vec{u}$ and $\vec{v}$ point in the opposite direction then $\vec{u} \cdot \vec{v} = -||\vec{u}||||\vec{v}||$.
#
# **Discuss**. Given these properties, how can we describe what the dot product is measuring?

# %% [markdown]
# ## 3.2 Functions
#
# Functional analysis isn't the focus of linear algebra (as compared to say, calculus) but functions are always there in the background. For example
#
#
# *   The magnitude of a vector is a function $f:\mathbb{R}^n ⟶ \mathbb{R}$.
# *   The dot product can be interpreted as $f: \mathbb{R}^n × \mathbb{R}^n ⟶ \mathbb{R}$.
#
# The most common way that functions show up directly in this course is in Python. We have already used quite a few built-in functions.
#
# **Discuss**. Name some functions that are "built-in" to base-Python. Name some functions that live in the Numpy library.
#
# From a computational efficiency standpoint, it's (almost) always better to use a function that has already been written (discuss how Python implements C subroutines and extensions here). That said, if we are working on a specialized problem and find ourselves reusing code (often this involves copy and pasting), we may want to write a new function that does this work for us.

# %% [markdown]
# ### Python Function Syntax.
#
# Python has special syntax (*def*, *return*, and indentation) for writing new functions.
#
#     *def* function_name(input1, input2,...):
#
#         Body of function that does the computing work goes here.
#
#         *return* outputs

# %% [markdown]
# **Exercise**. Write a function called ```vec_sq``` that takes a vector ```w``` as an input and returns a vector with ```w```'s elements squared. Test this function on one of the vectors we previously created.

# %%
# Testing. "Call" the vec_sq function and save it's result as "result_1"
result_1 = ???

# %% [markdown]
# **Angle Theorem**: $\vec{u} \cdot \vec{v} = cos(\theta_{u, v})||\vec{u}||*||\vec{v}||$.
#
# This is an expression that relates the angle between vectors $\vec{u}$ and $\vec{v}$ to their dot product.

# %% [markdown]
# **Exercise**. You are a programmer working for NASA. Your team needs to know the angle between a satellite (currently traveling along trajectory $\vec{s}$) and a rocket (that will push the satellite along trajectory $\vec{r}$).  Write a Python function called ```vec_angle``` that takes vectors ```s``` and ```r``` as inputs and returns the angle between them (in degrees). Test your work on vectors $\vec{s}_{test} = <10, 0>$ and $\vec{r}_{test} = <10, 10>$. Hint: import the ```math``` library!

# %%
import numpy as np
import math
s_test = np.array([[10], [0]])
r_test = np.array([[10], [10]])

# %%
# Write the function.

# %%
# Call and test the function.
