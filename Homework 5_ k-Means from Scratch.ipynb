# %% [markdown]
# ## 5.1 k-Means From Scratch
#
# A reminder for the following exercises: it's very important that you pay close attention to what cells have (and have not run). An easy mistake to make is thinking a group representative has updated when it hasn't in Python. Use the $\{x\}$ variable inspector on the left to help keep track of this!
#
# Consider the following dataset:
#
# A  | B
# ----|----
# 0 | 1
# 1 | 1
# 0 | 0
# 4 | 5
# 5 | 3
# 0 | 7
#
#
# In the following exercises you will run the k-Means algorithm from scratch like we did in class.

# %% [markdown]
# **Exercise 1**. Enter this dataset into Python as an ```ndarray```, then separately define each vector that will be grouped. There are \_\_\_ (number) individual \_\_\_\_\_\_ vectors that live in \_\_\_\_\_\_ (mathematical) dimensional space.

# %% [markdown]
# **Exercise 2**. For this exercise, the group representative vectors are randomly assigned to be $\vec{z}_0 = \vec{x}_0$, $\vec{z}_1 = \vec{x}_1$, and $\vec{z}_2 = \vec{x}_4$. This implies that there are __ total groups.

# %% [markdown]
# **Exercise 3**. Calculate and report $J^{clust}_0$.

# %%
X = ??

# %%
z_0 =
z_1 =
z_2 =

# %% [markdown]
# **Exercise 4**. After the first time the group representatives update $\vec{z}_2$ = [__ , 4].

# %% [markdown]
# **Exercise 5**. Calculate and report $J^{clust}_1$.

# %% [markdown]
# **Exercise 6**. The final optimal grouping once the K-Means algorithm has converged has a $J^{clust}$ value of ___.

# %% [markdown]
# **Exercise 7**. The smallest value $J^{clust}$ could ever achieve for this problem (or any k-Means problem) is __, and we could make this happen by
# choosing $k = $ __. Hint: Think about how $J^{clust}$ is calculated.
#
# Make sure you understand why using this $k$ this would not be a good idea!

# %% [markdown]
# ## 5.2 Free-Response Exam Questions
#
# **Exercise 8**. What is the "objective function" that we are using in the k-Means grouping algorithm? What is algorithm trying to do mathematically with the objective function? Why does this make sense, given what we are trying to achieve? Consider your answer to Exercise 7. Why is doing this a bad idea? What conclusions can you draw about model training being too narrowly focused on the objective function?
#
# **Exercise 9**. Explain the difference between supervised and unsupervised learning. Give examples to illustrate your answer.
#
# **Exercise 10**. How is $J^{clust}$ similiar to the Root-Mean-Square? How is it different, and how does this difference relate to the previous exercise?
#
# **Exercise 11**. What if you had access to a categorical variable $C$ for the dataset you used in the previous exercises. What might this indicate about our choice of $k$?
#
# A  | B  | C
# ----|----|----
# 0 | 1 | 0
# 1 | 1 | 1
# 0 | 0 | 1
# 4 | 5 | 0
# 5 | 3 | 1
# 0 | 7 | 0
#
# **Exercise 12**. Challenge Problem! Write code that implements the k-Means algorithm from scratch in a single cell. Test your work on the 5.1 exercises from this homework. Once your code is correct write a function called ```k_means_from_scratch``` that takes a ```ndarray``` ```X```, and a number of groups ```k``` as inputs, returns nothing, but prints a line or two indicating how the vectors were grouped, how many iterations it took to do so, and the final value of $J^{clust}$.
#
# I recommend fully understanding Section 5.5 in [Lecture 5](https://colab.research.google.com/drive/1zSmntNtn9EnFqObH8-5Im_z361yS1Xev?usp=sharing) before you do this exercise.
#
# To be clear: I don't expect you to know how to code using for and while-loops for this class, but these are the tools that we can use to implement k-Means in a single code cell and are standard things to know how to use when working with data. You can read about these techniques in the *Control Flow* section of *Practical Linear Algebra for Data Science* on pages 297 - 300.
