# %% [markdown]
# ## 2.0 Introduction
#
# The purpose of this homework (and all homeworks in this class) is to get your more practice and exposure with the concepts we discussed during lecture.  Complete the following exercises here in Colab and submit your answers in the quiz shell in Canvas.
#
# ### Things to keep in mind for entering work in Canvas.
#
# 1. You can (and should) submit your answers as many times as you like in Canvas, up to the homework due date. There's no penalty for wrong answers.
#
# 2. I'll grade the latest submission; make sure that the last version you submit is the submission version you want me to grade!
#
# 3. Most homework exercises will be automatically graded in Canvas. This means that you need to get everything  (spaces, punctuation, capitalization, rounding, etc) *just* right in order to get credit for your work. This will require a lot of careful work and trouble-shooting! If you get an answer wrong it may be the case that it is only slightly wrong.
#
#
# ### The Big Picture: Why are you doing homework?
#
# The point of doing homework isn't just to get it done; it's meant to be a guided learning experience that reinforces and expands on topics we discussed in class. Take your time with these! Don't copy answers from your classmates or the internet or use a Large Language Model like ChatGPT; if you do you won't learn and you'll do poorly on exams. As your instructor I can't force you to learn linear algebra, all I can do is offer structured learning opportunities. If you engage in this process and take it seriously you'll enjoy this class and be better prepared for future opportunities. Budget a fair amount of time for these exercises. Some of them will you'll know how to do right away, some require reflection, trial and error, and a little bit of research. Making mistakes and engaging in this process can be tedious but it's the best way to learn!
#
# Note that ```code``` is generally typset ```like this``` when not entered in a code cell.
#
# **For all homework assignments, round all answers to 4 decimal values (where necessary).**

# %% [markdown]
# **Exercise 0**. "I acknowldge that I have fully read and reflected on the information above. I understand that my success in this course will depend on my motivation to work and think independently of other students and internet resources. If I use other resources (such as other students, LLMs like ChatGPT, etc) I am shortchanging myself and my own learning process. I will also likely perform poorly on quizzes and exams. Additionally, using these resources and misrepresenting their work as my own is academically dishonest and carries consequences (please refer to the course syllabus for more information about this)."

# %% [markdown]
# ## 2.1 Vectors in Python

# %% [markdown]
# Use the ```numpy``` library to construct the following vectors. Do the following exercises by writing code in Python.
#
# $w = <4, 0, 9, -9, 8, -2, 19, 2, 1>$
#
# $v = <-2, 3, 7>$
#
# $u = <-1, -4, 5>$
#
# $z = [4, 2.1, -8]$

# %%
# Import statement comes first!

# %% [markdown]
# **Exercise 1**. Write code to construct a new vector $\vec{g} = 2\vec{v} - 3\vec{u} + 4\vec{z}^T$. The second entry of $\vec{g}$ is \_\_.

# %% [markdown]
# **Exercise 2**. The dimensions ("shape") of $\vec{w}$ are ```(__ , __)```, and the dimensions of $\vec{w}^T$ are ```(__ , __)```.

# %% [markdown]
# **Exercise 3**. Find $||\vec{w}||$.

# %% [markdown]
# **Exercise 4**. Construct a vector called ```new_vec``` that points in the opposite direction of $\vec{v}$ and has $||\vec{new\_vec}|| = 4$. It's second entry is \_\_.

# %% [markdown]
# **Exercise 5**. What is the distance between the tips of $\vec{v}$ and $\vec{u}$?

# %% [markdown]
# **Exercise 6**. The code ```np.zeros((1,100))``` can be used to construct a \_\_\_\_\_\_\_\_\_\_ (column, row) vector of zeros in $\mathbb{R}^n$, where $n$ = \_\_\_\_\_.

# %% [markdown]
# **Exercise 7**. True or False: ```np.linalg.norm(np.array([[1], [1], [1], [1]]))``` will return ```1```.

# %% [markdown]
# ## 2.2 Free-Response Exam Exercises
#
# You will take 3 in-class exams in this class: Exam 1 (12.5%), Exam 2 (12.5%) and the Final Exam (25%). **Exams will consist of questions that are very similar to the exercises you do in the homework. The best way to prepare for exams is to take each and every homework exercise seriously.**
#
# One type of question that you can expect to see in an exam (but not in homework) is free-response "explain" questions. In an exam, each of these will focus on a particular topic. I'll end each homework with some ungraded examples of these types of questions. I'm not going to publish an answer key for these questions but I am happy to disucss them with you during office hours!
#
# ### Things to keep in mind when answering free-response exercises.
#
# In general I expect free-form responses, such as "explain" or "discuss" to be:
#
# 1. Full sentences with proper grammar, punctuation, capitalization, etc.
#
# 2. Well-organized and logically coherent- do the sentences make sense when read together? Do they respond to the prompt?
#
# 3. Reflective of what we have learned in class and homeworks.
#
# Here are some examples of the type of questions from Homework 2 topics that you might see on an in-class exam. Practice and test your knowledge of the material by writing answers to these questions as you would in an exam. If you double click on the cell containing each **Exercise** you can type your answers (this is *editing* a text cell in a Colab notebook, as compared with editing a code cell).

# %% [markdown]
# **Exercise 8**. What is ```numpy```, what code is used to access it, and what do we use it for?

# %% [markdown]
# **Exercise 9**. Write code that will create a new vector ```u1``` that is a unit vector that points in the same direction of a vector ```v1```.

# %% [markdown]
# **Exercise 10**. What does $n$ represent in $\mathbb{R}^n$? What is the highest number of dimensions for which we can visually graph a vector and why?
