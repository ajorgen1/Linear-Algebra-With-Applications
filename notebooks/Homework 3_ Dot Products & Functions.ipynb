# %% [markdown]
# **Instructions**. Re-read [Section 2.0 in Homework 2](https://colab.research.google.com/drive/1ZJnofJhNnzP2555JrI5MasHkXgirMJad?usp=sharing).
#
# ## 3.1 Dot Products and Functions
#
#
# **Exercise 1**. Suppose that you find $<1, 2, 3> \cdot <-1, 1, a> = 10$. This implies that $a = \_\_$.
#
# **Exercise 2**. True or False: Suppose $\vec{v} \cdot \vec{u} = 0$. We can conclude that $\vec{v}$ and $\vec{u}$ are orthogonal.

# %% [markdown]
# **Definition**. The <u>root-mean-square</u> of a vector $x$ is defined as:
#
# \begin{align}
# RMS = \sqrt{\frac{\sum_{i=1}^n x_i^2}{n}}.
# \end{align}
# The RMS and its variations are commonly used to measure the accuracy of a machine learning algorithm's performance (we'll study this in detail in Week 9).

# %% [markdown]
# **Exercise 3**. Write a Python function called ```rms_1``` that takes a vector $x$ as an input and returns its root-mean-square. Test your function on ```np.array([[-1], [1]])```; make sure it returns ```1```.
#
# For ```v = np.array([[-1], [2], [3], [5]])```, ```rms(v)```= \_\_.
#
# Hints: There are a couple different ways you can do this. You could compute $\sum_{i=1}^n x_i^2$ as a dot product like we did in class. Alternatively you could use the ```sum()``` function. You could also write a ```for``` loop to do this, though the previous two approaches make this unnecessary.
#
# ```rms(w)``` = ___.

# %% [markdown]
# **Exercise 4**. The RMS is often used to compare a vector of data values $y$ to a vector of *estimates* (guesses) $\hat{y}$ that a model produces to predict $y$.
#
# \begin{align}
# RMSE = \sqrt{\frac{\sum_{i=1}^n (y_i - \hat{y}_i)^2}{n}}.
# \end{align}
#
# Write a function called ```rms_2``` that takes column vectors ```y``` and ```y_hat``` as inputs and returns the root-mean-squared of the *differences* between the components of $y$ and $\hat{y}$. Test your function on ```np.array([[1], [-1]])``` and ```np.array([[-1], [1]])```; make sure it returns ```2.0```.
#
# For ```v = np.array([[-1], [2], [3], [5]])``` and ```v_hat = np.array([[0], [1], [4], [3]])```, ```rms_2(v, v_hat)``` = \_\_.
#
# Hint: You can re-use code from ```rms_1```! What relatively small modifications do you need to make?

# %% [markdown]
# ## 3.2 Free-Response Exam Questions
#
# **Exercise 5**. Explain how we can think of vectors as matrices. If $\vec{v}$ is a column vector in $\mathbb{R}^m$, what are its dimensions? If $\vec{u}$ is a row vector in $\mathbb{R}^m$, what are its dimensions? If these vectors were in Python, how do these questions relate to using the ```shape``` method?
#
# **Exercise 6**. Assuming ```u``` and ```v``` are column vectors, why do we need to use the transpose operator when computing ```np.dot(u.T, v)```?
#
# **Exercise 7**. Explain the difference between scalar-vector multiplication and vector-vector multiplication. Intuitively, what does the dot product tell us? If the dot product between two vectors is negative, what can we conclude about how these vectors are positioned (compared to each other)?
#
# **Exercise 8**. Write a function called ```dist``` that takes vectors ```u``` and ```v``` as inputs and returns the distance between their tips.

# %% [markdown]
# **Exercise 9**. Suppose ```u``` and ```v``` are row vectors. Write code (using the ```numpy``` library) to compute their dot product. Be sure to test your code on some simple examples to make sure it runs as you expect.
