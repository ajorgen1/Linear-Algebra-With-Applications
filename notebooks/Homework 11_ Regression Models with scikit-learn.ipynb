# %% [markdown]
# ## 11.1 True or False
#
# **Exercise 1**. True or False: When using scikit-learn to build a linear regresion model you need to insert a column of 1s into the design matrix $\mathbf{X}\mathrm{.}$
#
# **Exercise 2**. True or False: When building a linear regression model using scikit-learn the ```.fit()``` method finds the "optimal" solution to $\mathbf{X}\boldsymbol{\beta} = \mathbf{y}$.
#
# **Exercise 3**. True or False: Metrics that measure model performance tend to focus on the amount of error the model is making with its predictions.
#
# **Exercise 4**. True or False: $R^2$ tells us (roughly) the overall "amount" of the predictions that "live" in the column space of the input variables.

# %% [markdown]
# ## 11.2 Linear Regression and the Swiss Dataset using scikit-learn
#
# The ```swiss``` data set contains standardized fertility measures and socio-economic indicators for 47 French-speaking provinces in Switzerland around 1888. You can read about the variables in the data set [here](https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/swiss.html). The goal of our model will be to predict a providence's ```Examination``` variable using the other variables in the data set as inputs.
#
# In [Homework 10](https://colab.research.google.com/drive/15nevniEocve4g683SgIf3kwr6A2yRrBo#scrollTo=3wGNU0cD5pWM&line=3&uniqifier=1) we built a least squares model to predict ```Examination```. In the following exercises let's construct a linear regression model of the form
#
# \begin{align}
# Examination = \beta_0 +  \beta_1Fertility + \beta_2Agriculture + \beta_3Education + \beta_4Catholic + \beta_5Infant\_Mortality + \epsilon
# \end{align}
#
# but this time we'll use the scikit-learn API to construct and train the model instead of building it "from scratch."
#
# **Exercise 5**. Use ```sklearn``` to build and train the the model described above to predict ```Examination```. This model explains \_\_\_\_% of the variation in ```Examination```. Round your percentage to two decimal places.
#
# Note: Unlike the ```babies``` dataset, there are no ```NaN``` values in the ```swiss``` dataset so you don't need to run any code to replace missing values.

# %%
from google.colab import files

uploaded = files.upload()

# %% [markdown]
# ## 11.3 Free-Response Exam Exercises
#
# **Exercise 6**. Write code to demonstrate how to find a linear regression model's $\mathbf{\hat{y}}$ two different ways: one by using the ```.predict()``` function, and the other using matrix-vector multiplication.
#
# **Exercise 7**. State a formula for the RMSE in terms of the SSR.
#
# **Exercise 8**. If a model has a (relatively) small SSR will it also have a small RMSE? Why or why not?
#
# **Exercise 9**. If a model's SSR goes up what happens to the model's $R^2$? What is the smallest SSR a model could ever achieve? What does that mean about $\mathbf{y}$ and $C(\mathbf{X})$? What would the $R^2$ be in this case?
#
# **Exercise 10**. Explain why $\mathbf{X}$ is generally considered to be size $n \times (p + 1)$ when solving $\mathbf{X}\boldsymbol\beta = \mathbf y$.
#
# **Exercise 11**. Explain why $\mathbf{X}$ will be $n \times p$ if you're building a linear regression model using the scikit-learn API.
