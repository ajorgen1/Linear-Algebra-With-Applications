# %% [markdown]
# ## 1.0 Jupyter Notebooks
#
# We'll be using the **Jupyter notebook** environment for notes and homework in this class. A Jupyter notebook is the interactive environment we're working in right now — it allows you to
# combine code, math, and text in a single document. There are two types of "cells" you can create and manipulate within the notebook: *markdown*, which is what this cell is written in, and `code`, which we'll see below. Markdown cells are good for plain text and mathematically typesetting ([latex code](https://www.latex-project.org)).
#
# The file itself is saved as an `.ipynb` file (short for "IPython Notebook"),
# which is just the format Jupyter uses to store your work on a disk.
#
# There are many different platforms that will run `.ipynb` files, each has advantages and disadvantages. Previous BIS 231 classes have used the Google Colab environment, for example. Jupyter isn't quite as user-friendly as Colab but it is the "industry standard" so I suggest using it for your notes and homework in this course.
#
# **Running Jupyter** — you have two options:
#
# - **Locally:** Install [Anaconda](https://www.anaconda.com/download) on your machine, which bundles Python, Jupyter, and all the libraries we'll use in one step. I recommend pairing this with [VS Code](https://code.visualstudio.com) and its Jupyter extension, which is how I'll be doing notes and homework. This is the setup I suggest.
#
# - **In the cloud:** If you'd prefer to avoid a local installation, [Anaconda Cloud](https://anaconda.com/app/) lets you run Jupyter notebooks directly in your browser with no setup required. I'll be running lectures from Anaconda Cloud, so you're welcome to follow along there.
#
# A **library** (also called a **package**) is a collection of pre-written code that extends what Python can do out of the box. Rather than writing everything from scratch, we import libraries to handle common tasks — math, data manipulation, plotting, and machine learning. We'll see our first example of this later today when we import **NumPy** to create and plot vectors.
#
# The most common difference between the local and cloud environments that students run into is **file management**: locally, your notebooks live on your machine and you control them directly; in the cloud, files are stored remotely and you'll need to upload/download them to submit homework. If you run into any environment-specific issues, bring these up in class!
#
# That said, navigating these kinds of discrepancies — different environments, package versions, file paths that work on one machine but not another — is a normal part of doing actual data science. Learning to troubleshoot your setup is a skill in itself, and one that will serve you well beyond this course.
#
# ### What Place Does AI-Assisted Coding Have in This Course?
#
# AI tools like Claude and ChatGPT are now a normal part of the data science landscape, and
# we won't pretend otherwise. That said, this course emphasizes **learning, not production** —
# the goal is for you to understand what the code is doing and why, not just to get a correct answer.
#
# With that in mind, here's the policy:
#
# - **Encouraged:** Using AI assistance to work through installation issues, debug error messages,
# or understand what a piece of code is doing. This is a reasonable use of the tools available to you.
#
# - **Strongly discouraged:** Using AI to write code for you on notes and homework. It's tempting,
# but it will leave you unprepared when it counts. This requires discipline — the work you put in now
# is what builds the intuition you'll need later.
#
# - **Not allowed:** AI assistance of any kind on exams and quizzes. Plan accordingly.
#
# The reality is that even professional data scientists who use AI tools daily need a solid
# understanding of the underlying math and code to use those tools well.

# %% [markdown]
# ## 1.1 Linear Algebra Applicaton: Data Science
#
# A <u>model</u> is a mathematical description of the relationship between two or more different variables. This kind of modeling is common in statistics, machine learning, dynamical systems, regression, and classification.
#
# <u>Data science</u> is the process of using data to formulate a model that gives us insight (reveals connections, makes predictions, etc) about an underlying phenomena that we wish to study. Modern data science involves tools from statistics, computer science, machine learning, and other areas of mathematics (depending on the specific application). Linear Algebra lies at the heart of data science and modeling applications, which is why we study it specifically in this course.
#
# **Example**: We are building a model to predict amount of money a customer will spend at website y using the amount of money they spent websites x and z as predictor variables. Here is some example data:
#
# x  | z  |  y
# ----|----|----
# 2 | 3 | 8
# 4 | 6 | 16
# 3 | 7 | 17
# 5 | 2 | 9
# 3 | 2 | 7
#
# There are many ways that we could use this data to build a model to predict how much money a new customer (who is not in the data set) will spend at website y. One way we could build a model is to assume that the amount spent at website y is a linear function of the amounts a customer spent at websites x and z:
#
# \begin{align}
# \hat{y} = w_1x + w_2z.
# \end{align}
#
# We use the "hat" symbol to distinguish between a model's *prediction* $\hat{y}$ and the actual data values $y$. To finish "building" this model we need to use the data to "learn" the model "weights" $w_1$ and $w_2$.
#
# One way to find the weights using the data is to set up the following **system of equations**:
#
# \begin{array}{lcl} 8 & = & 2w_1  + 3w_2
# \\ 16 & = & 4w_1  + 6w_2
# \\ 17 & = & 3w_1 + 7w_2
# \\ 9 & = & 5w_1 +  2w_2
# \\ 7 & = & 3w_1 + 2w_2 \end{array}
#
# Using **matrix algebra** to find a solution to this sytem of "5 equations in 2 unknowns" is a classic linear algebra task. If we can find values for $w_1$ and $w_2$ that satisfy all 5 of these equations then we plug these numbers into $\hat{y} = w_1x + w_2z$ and use the resulting equation to predict $y$ values that aren't in our original dataset (practitioners would call this "model deployment").
#
# The mathematical process of actually finding $w_1$ and $w_2$, and whether these values exist in the first place, is complicated. We'll spend a considerable amount of time in this course developing techniques and intuition to solve problems like these.
#
# **Question**. The above dataset is an example of **synthetic** data, made for illustration purposes only. Can anyone spot the "obvious" values for $w_1$ and $w_2$? There's something fundamentally "fake" and unrealistic about this dataset, what is it?

# %% [markdown]
# ## 1.2 Vectors
#
# **Definition.** A **vector** is a mathematical object that has *magnitude* (length) and *direction*. Vectors come in two *orientations*:
#
# **A column vector in $\mathbb{R}^n$**:
#
# $$\mathbf{x} = \begin{bmatrix} x_{1} \\ x_{2} \\ \vdots \\ x_{n} \end{bmatrix}$$
#
# **A row vector in $\mathbb{R}^n$:**
#
# $$\mathbf{x}^T = \begin{bmatrix} x_{1} & x_{2} & \cdots & x_{n} \end{bmatrix}$$
#
# The $T$ is called the **transpose** operator — it converts a column vector $\mathbf{x}$ to a row vector $\mathbf{x}^T$, and vice versa. Column vectors are the default orientation in this course, but we'll work with both.
#
# The numbers inside a vector are called its **components** (also called *entries*, *elements*, or *features*). The **index** tells you which component is which: $x_1$ is the first, $x_n$ is the $n^{th}$. We often use $i$ as a dummy variable to refer to an arbitrary component — $x_i$ could be any of them, so when $i = 2$ we mean $x_2$.
#
# The general column vector above lives in $n$-dimensional space. It's *general* because we name the components ($x_1, x_2, \ldots, x_n$) without specifying what those numbers are.
#
# ### Examples.
#
# $$\mathbf{v} = \begin{bmatrix} 2 & 3 & 7 \end{bmatrix}, \qquad \mathbf{x} = \begin{bmatrix} 2 & 4 & 3 & 5 & 3 \end{bmatrix}^T, \qquad \mathbf{0} = \begin{bmatrix} 0 \\ 0 \\ 0 \\ 0\end{bmatrix}, \qquad \mathbf{u} = \begin{bmatrix} \cos(\frac{\pi}{2}) \\ \sin(\pi)\end{bmatrix}^T$$
#
# **Question.** What is the orientation (row or column) of each vector, and in what "space" does each live?

# %% [markdown]
# ## 1.3 Matrices
#
# **Definition.** A **matrix** is a rectangular array of numbers with $m$ rows and $n$ columns,
# written $A \in \mathbb{R}^{m \times n}$. Read "$\in$" as "in," or "is an element of, or more informally "lives in". (Double click on this cell to see the latex code for creating $\in$!) We can think of a matrix in two ways:
#
# **As a collection of column vectors:**
#
# $$A = \begin{bmatrix} \mathbf{a}_1 & \mathbf{a}_2 & \cdots & \mathbf{a}_n \end{bmatrix}$$
#
# where each $\mathbf{a}_j \in \mathbb{R}^m$ is a column vector.
#
# **As a stack of row vectors:**
#
# $$A = \begin{bmatrix} \mathbf{a}_1^T \\ \mathbf{a}_2^T \\ \vdots \\ \mathbf{a}_m^T \end{bmatrix}$$
#
# where each $\mathbf{a}_i^T \in \mathbb{R}^n$ is a row vector.
#
# Both perspectives are useful — we'll see that the column view connects naturally to
# datasets, where each column represents a measured variable (or *feature*), and each
# row represents a single observation.
#
# ### Example.
#
# $$A = \begin{bmatrix} 2 & 3 & 8 \\ 4 & 6 & 16 \\ 3 & 7 & 17 \\ 5 & 2 & 9 \\ 3 & 2 & 7 \end{bmatrix}$$
#
#
# **Questions**.
#
# - What are the *m* by *n* dimensions for $A$?
# - How can we see $A$ as a collection of vectors?
# - What dimensional space(s) do these vectors live in?
# - There's a natural connection between **tabular data** and matrices- do you see it?

# %% [markdown]
# ## 1.4 Vectors and Matrices in Python: the `numpy` Library
#
# Python is an *object-oriented* programming language, which means that getting stuff done is all about creating (and sometimes naming) objects in the computer's working memory. Here are some object types that you can create with "base" Python:
#
# | Type | Example | Description |
# |------|---------|-------------|
# | `int` | `x = 3` | Integer |
# | `float` | `x = 3.0` | Decimal number |
# | `str` | `x = "hello"` | Text |
# | `bool` | `x = True` | True or False |
# | `list` | `x = [1, 2, 3]` | Ordered, mutable sequence |
# | `tuple` | `x = (1, 2, 3)` | Ordered, immutable sequence |
# | `dict` | `x = {"a": 1}` | Key-value pairs |
#
# Notice that vectors and matrices are not on that list. It's possible to represent them with lists and tuples, but a (much) better way is to use the `numpy` library.
#
# ### Examples.
#
# Create some code cells below and use the `numpy` library to create the vectors and matrices we saw the examples above. What does `.T` do?
